# %% [markdown]
# # Assignment 1

# %%
def Checkerboard(a):
    for i in range(a):
        if i % 2 == 1:
            print(" "+ a*'*')
        else :
            print(a*'*')

# %%
x = input("How many times do you want it to be printed?")
times = int(x)
Checkerboard(times)
# Out:
# How many times do you want it to be printed?5
# *****
#  *****
# *****
#  *****
# *****

# %% [markdown]
# # Assignment 2

# %%
pos = -1
def search(arr, n):
    l = 0
    u = len(arr)-1
  
    while l <= u:
        mid = (l+u) // 2
    
        if arr[mid] == n:
            globals()['pos'] = mid
            break
        else:
            if arr[mid] < n:
                l = mid + 1
            else:
                u = mid - 1 
arr = list(map(int,input("Input an array:").split()))
arr.sort()
print(arr)
n=int(input("Which number are you looking for?"))
search(arr,n)
if pos == -1 :
    print("Not found")
else:
    print("Found at ",pos)
# Out:
# Input an array:2 3 4 4 5
# [2, 3, 4, 4, 5]
# Which number are you looking for?4
# Found at  2

# %% [markdown]
# # Assignment 3

# %%
def insert(arr,n):
    arr.append(n)
    temp = n
    a = len(arr) -1
    for i in range(a-1,-1,-1):
        if arr[i] > temp:
            arr[i+1] = arr[i]
        else:
            arr[i+1] = temp
            break
    if arr[0] >= temp:
        arr[1] = arr[0]
        arr[0] = temp

# %%
arr = [-2, 0, 2, 3 , 4, 6, 8, 9, 10]
insert(arr,-10)
print(arr)
# Out:
# [-10, -2, 0, 2, 3, 4, 6, 8, 9, 10]

# %% [markdown]
# # Assignment 4

# %%
txt = "hellothereamiamhereiamherehellothereamcoming"
txt1 = "sisisis"
txt2 = "1111111"

size = len(txt2)

for i in range(size-2):
    for j in range(size-1,0,-1):
        a = i
        b = j
        while b < size:
            x = txt2[a:b] in txt2[a+1:size]
            if x :
                print(len(txt2[a:b]))
                print(txt2[a:b])
                break
            else:
                a = a+1
                b = b+1
        if x:
            break
    if x:
        break
# Out:
# 6
# 111111

# %% [markdown]
# # Assignment 5

# %%
text="good morning my name is tresor and i am currently running at the football field today the weather is very cool because it is too early there are few people in the street"

#Split the string into an array with one block for a word
arr1 = text.split()

#Getting the index of each word in the text and store them in an array
arr2 = []
index = 1
for i in range(len(arr1)):
    currWord = arr1[i]
    arr2.append(index)
    index += len(arr1[i]) + 1

#Creating an empty hash table
hash_table = [[] for _ in range(40)]

#Insert every word with its corresponding index
def insert(hash_table, key, value):
    hash_key = hash(key) % len(hash_table)
    key_exists = False
    bucket = hash_table[hash_key]
    for i, kv in enumerate(bucket):
        k, v = kv
        if key == k:
            key_exists = True
            break
    if key_exists:
        bucket[i] = ((key, value))
    else:
        bucket.append((key, value))    

#Search through the table using the word we are looking for as a key
def search(hash_table, key):
    hash_key = hash(key) % len(hash_table)
    bucket = hash_table[hash_key]
    for i, kv in enumerate(bucket):
        k, v = kv
        if key == k:
            return v

#Using our insert function to store the words in the text with their index      
for i in range(len(arr1)):
    insert(hash_table, arr1[i], arr2[i])
print(search(hash_table,"currently"))
print(search(hash_table,"good"))
print(search(hash_table,"running"))
print(search(hash_table,"football"))
print(search(hash_table,"today"))
print(search(hash_table,"because"))
# Out:
# 41
# 1
# 51
# 66
# 81
# 112

# %% [markdown]
# # Assignment 6

# %%
import itertools
global n, m, k, edge,ind,outd,indv, outdv,head, dist, stack, vis, nMax,mMax, inf

nMax = 100
mMax = 100
inf = 10000

#Build a graph
class g(object):
    pass
  
n = 0
m = 0  
k = 0  
ind = [0]
outd = [0]
head = [0]
dist = [0]
stack = [0]
vis = [0]
indv = []
outdv = []
#Declare an empty array that will hold the edges
edge = []

# Function that will add edges to the array edge[]
def add(u,v,w):
    global k, edge, head
    ed = g()
    ed.u = u
    ed.v = v
    ed.w = w
    ed.next = head[u]
    edge.append(ed)
    head[u] = k
    k += 1 

#Function that find the shortest path from a given starting point to any other point in the graph
def shortestdist(start):
    global n,m,k, edge, head, dist, stack, vis, inf
    i = top = 0
    for i in range(n):
        dist[i] = inf
        vis[i]  = 0  
    dist[start] = 0
    vis[start] = 1
    top += 1
    stack[top] = start
    while(top!=0):
        u =stack[top]
        top -= 1
        i = head[u]
        while(i!=0):
            v = edge[i].v
            if dist[v] > dist[u] + edge[i].w:
                dist[v] = dist[u] + edge[i].w
                if(vis[v]==0):
                    vis[v] = 1
                    top += 1
                    stack[top] = v
            i = edge[i].next
        vis[u] = 0
          

       

 #The main method
if __name__ == '__main__':
    u = v = w = i = 0
    for i in range(nMax):
        ind.append(0)
        outd.append(0)
        head.append(0)
        dist.append(0)
        vis.append(0)
        stack.append(0)

    na,ma = input().split()
    n = int(na)
    m = int(ma)
    edge = [0]
    k = 1
    sum1 = 0
    for i in range(n):
        head[i] = 0
    # Input the edges  
    for i in range(m):
        ua,va,wa = input().split()
        u = int(ua)
        v = int(va)
        w = int(wa)
        outd[u] += 1
        ind[v] += 1
        add(u,v,w)
        sum1 += w
  
    #Store the odd vertices in 2 arrays(Those that need an additional indegree and outdegree)
    for i in range(n):
        if ind[i] > outd[i]:
            outdv.append(i)
        elif outd[i] > ind[i]:
            indv.append(i)
    #Create a list of all possible combinations from the odd vertices
    a=[zip(x,indv) for x in itertools.permutations(outdv,len(indv))]
    chain = itertools.chain(*a)
    aa = list(chain)
  
    #find the least dist from those combinations of odd vertices
    if len(outdv) < 1:
        min_dist = 0
    else:    
        min_dist = inf
        count = 0
        sup = len(indv) - 1
        while count < len(aa)-sup:
            cost = 0
            for j in range(count,count+len(indv)):
                shortestdist(aa[j][0])
                cost += dist[aa[j][1]]
            count += len(indv)
            min_dist = min(min_dist,cost)  

    #Print the shortest distance
    if n > m:
        print(-1)
    else:  
        print(sum1 + min_dist)
# Out:
# 4 4
# 0 1 1
# 1 2 2
# 2 3 3
# 3 0 4
# 10

# %% [markdown]
# # Draft

# %%
import networkx as nx
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib notebook
sns.set()


import itertools
global n, m, k, edge,ind,outd,indv, outdv,head, dist, stack, vis, nMax,mMax, inf

nMax = 100
mMax = 100
inf = 10000

#Build a graph
class g(object):
    pass
  
n = 0
m = 0  
k = 0  
ind = [0]
outd = [0]
head = [0]
dist = [0]
stack = [0]
vis = [0]
indv = []
outdv = []
#Declare an empty array that will hold the edges
edge = []

# Function that will add edges to the array edge[]
def add(u,v,w):
    global k, edge, head
    ed = g()
    ed.u = u
    ed.v = v
    ed.w = w
    ed.next = head[u]
    edge.append(ed)
    head[u] = k
    k += 1 

#Function that find the shortest path from a given starting point to any other point in the graph
def shortestdist(start):
    global n,m,k, edge, head, dist, stack, vis, inf
    i = top = 0
    for i in range(n):
        dist[i] = inf
        vis[i]  = 0  
    dist[start] = 0
    vis[start] = 1
    top += 1
    stack[top] = start
    while(top!=0):
        u =stack[top]
        top -= 1
        i = head[u]
        while(i!=0):
            v = edge[i].v
            if dist[v] > dist[u] + edge[i].w:
                dist[v] = dist[u] + edge[i].w
                if(vis[v]==0):
                    vis[v] = 1
                    top += 1
                    stack[top] = v
            i = edge[i].next
        vis[u] = 0
       

 #The main method
if __name__ == '__main__':
    u = v = w = i = 0
    for i in range(nMax):
        ind.append(0)
        outd.append(0)
        head.append(0)
        dist.append(0)
        vis.append(0)
        stack.append(0)

    na,ma = input().split()
    n = int(na)
    m = int(ma)
    edge = [0]
    k = 1
    sum1 = 0
    G = nx.DiGraph()
    for i in range(n):
        head[i] = 0
    # Input the edges  
    for i in range(m):
        ua,va,wa = input().split()
        u = int(ua)
        v = int(va)
        w = int(wa)
        outd[u] += 1
        ind[v] += 1
        add(u,v,w)
        G.add_edge(u,v, weight = w)
        sum1 += w
  
    #Store the odd vertices in 2 arrays(Those that need an additional indegree and outdegree)
    for i in range(n):
        if ind[i] > outd[i]:
            outdv.append(i)
        elif outd[i] > ind[i]:
            indv.append(i)
    #Create a list of all possible combinations from the odd vertices
    a=[zip(x,indv) for x in itertools.permutations(outdv,len(indv))]
    chain = itertools.chain(*a)
    aa = list(chain)
  
    #find the least dist from those combinations of odd vertices
    if len(outdv) < 1:
        min_dist = 0
    else:    
        min_dist = inf
        count = 0
        sup = len(indv) - 1
        while count < len(aa)-sup:
            cost = 0
            for j in range(count,count+len(indv)):
                shortestdist(aa[j][0])
                cost += dist[aa[j][1]]
            count += len(indv)
            min_dist = min(min_dist,cost)  

    #Print the shortest distance
    if n > m:
        print(-1)
    else:  
        print(sum1 + min_dist)  
    
    plt.figure()
    nx.draw_networkx(G)
# Out:
# 4 7
# 0 1 1
# 1 2 2
# 2 3 3
# 3 0 4
# 1 3 5
# 3 1 2
# 1 3 2
# 21
# <img src="data:image/png;base64,..." width="640">
